# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# This was because my file is saved in excel
# Please download the 'creditcard.csv' dataset and open it in excel if you want
# inspect or modify it. Then save/export it as a csv file, and then proceed with
# the code
from google.colab import files
upload = files.upload()
df = pd.read_csv('creditcard.csv')
df
# Out:
#      <input type="file" id="files-c69ff7f1-33bc-42fd-9d3a-cfc67f665a24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c69ff7f1-33bc-42fd-9d3a-cfc67f665a24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# List First five values in this dataset
print(df.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# List the last five values in the dataset
print(df.tail())
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# Information of this dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Checking for missing values per column
print(df.isnull().sum())
# according to this I did not find even 1
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())


df = df.drop_duplicates()
print(df.shape)
# This (283726, 31) means 283,726 rows transactions and 31 columns features in dataset
# Out:
# Number of duplicate rows: 1081
# (283726, 31)

# %%
# Distrubution of legit vs fraud transactions
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
# Seperate fraud and legit transactions
fraud = df[df['Class'] == 1]
legit = df[df['Class'] == 0]

print(legit.shape)
print(fraud.shape)
# 473 are the legit transactions
# 283253 are the fraud transactions
# Out:
# (283253, 31)
# (473, 31)

# %%
# If this code does not work go to the top of the page and paste matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(legit['Amount'], bins=50, color='blue', label='Legit', stat='density',kde=True)
sns.histplot(fraud['Amount'], bins=50, color='red', label='Fraud', stat='density',kde=True)
plt.legend()
plt.title('Transaction Amount Distribution')
plt.xlim(0, 500)
plt.show()
#

# %%
# Separate features and target
X = df.drop(['Time', 'Class'], axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
# Single train-test split for both models
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
# Scale features only for logistic regression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(random_state=42, max_iter=1000)
lr_model.fit(X_train_scaled, y_train)
lr_pred = lr_model.predict(X_test_scaled)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Evaluate
from sklearn.metrics import confusion_matrix
print("LR confusion matrix:")
print(confusion_matrix(y_test, lr_pred))
print("LR classification report:")
print(classification_report(y_test, lr_pred))

# According to the random forest classification report 1 was fraud and 0 was valid
# So precision for 1 was 84%, recall was 56%, f1-score was 67%, 142 tranaction
# were fraud
# Also tells the same story with the confusion matrix which was 84961 tranaction
# were True Negative, 15 was false Positive, 63 was false negative, and 79 was
# true positive
# overall more are not fraud or valid.
# Out:
# LR confusion matrix:
# [[84961    15]
#  [   63    79]]
# LR classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.84      0.56      0.67       142
#
#     accuracy                           1.00     85118
#    macro avg       0.92      0.78      0.83     85118
# weighted avg       1.00      1.00      1.00     85118
